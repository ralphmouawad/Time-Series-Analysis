# %% [markdown]
# # Time Series Foundation Models
#
# In this lab, you will compare foundation-model-based approaches for time series
# classification and forecasting. You will:
# - Use **MANTIS** (a lightweight TSC foundation model) and **MultiROCKET** (a fast
#   feature-based baseline) on a classification task
# - Use **TiReX** for probabilistic forecasting on the ETTh dataset and visualize predictions with uncertainty intervals
#
# Docs for those models are available at:
# - [Mantis](https://github.com/vfeofanov/mantis)
# - [MultiRocket](https://www.aeon-toolkit.org/en/stable/api_reference/auto_generated/aeon.transformations.collection.convolution_based.MultiRocket.html)
# - [TiReX](https://github.com/NX-AI/tirex)

# %% [markdown]
# ## Part 0: Setup
#
# **Question 0.** Install the required packages: `mantis-tsfm` (MANTIS), `aeon`
# (MultiROCKET and data utilities), and `tirex-ts` (TiReX forecaster).

# %%
# !pip install mantis-tsfm aeon tirex-ts
# Out:
# Collecting mantis-tsfm
#   Downloading mantis_tsfm-1.0.0-py3-none-any.whl.metadata (10 kB)
# Collecting aeon
#   Downloading aeon-1.3.0-py3-none-any.whl.metadata (21 kB)
# Collecting tirex-ts
#   Downloading tirex_ts-1.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: datasets>=4.0 in /usr/local/lib/python3.12/dist-packages (from mantis-tsfm) (4.0.0)
# Requirement already satisfied: einops<0.9,>=0.8 in /usr/local/lib/python3.12/dist-packages (from mantis-tsfm) (0.8.2)
# Requirement already satisfied: huggingface-hub>=0.23 in /usr/local/lib/python3.12/dist-packages (from mantis-tsfm) (1.5.0)
# Requirement already satisfied: numpy<3.0,>=1.23 in /usr/local/lib/python3.12/dist-packages (from mantis-tsfm) (2.0.2)
# Requirement already satisfied: pandas<3.0,>=1.5 in /usr/local/lib/python3.12/dist-packages (from mantis-tsfm) (2.2.2)
# Collecting safetensors<0.5,>=0.4 (from mantis-tsfm)
#   Downloading safetensors-0.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: scikit-learn<2.0,>=1.2 in /usr/local/lib/python3.12/dist-packages (from mantis-tsfm) (1.6.1)
# Requirement already satisfied: torch<3.0,>=1.12 in /usr/local/lib/python3.12/dist-packages (from mantis-tsfm) (2.10.0+cpu)
# Requirement already satisfied: tqdm<5.0,>=4.64 in /usr/local/lib/python3.12/dist-packages (from mantis-tsfm) (4.67.3)
# Collecting deprecated>=1.2.13 (from aeon)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numba<0.62.0,>=0.55 in /usr/local/lib/python3.12/dist-packages (from aeon) (0.60.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from aeon) (26.0)
# Collecting scipy<1.16.0,>=1.9.0 (from aeon)
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from aeon) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=4.0->mantis-tsfm) (3.24.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.0->mantis-tsfm) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.0->mantis-tsfm) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.0->mantis-tsfm) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=4.0->mantis-tsfm) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.0->mantis-tsfm) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.0->mantis-tsfm) (6.0.3)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.13->aeon) (2.1.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23->mantis-tsfm) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23->mantis-tsfm) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23->mantis-tsfm) (0.24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<0.62.0,>=0.55->aeon) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.5->mantis-tsfm) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.5->mantis-tsfm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.5->mantis-tsfm) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0,>=1.2->mantis-tsfm) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0,>=1.2->mantis-tsfm) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=1.12->mantis-tsfm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=1.12->mantis-tsfm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=1.12->mantis-tsfm) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=1.12->mantis-tsfm) (3.1.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23->mantis-tsfm) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23->mantis-tsfm) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23->mantis-tsfm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23->mantis-tsfm) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23->mantis-tsfm) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.5->mantis-tsfm) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=4.0->mantis-tsfm) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=4.0->mantis-tsfm) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=1.12->mantis-tsfm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=1.12->mantis-tsfm) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23->mantis-tsfm) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23->mantis-tsfm) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23->mantis-tsfm) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.23->mantis-tsfm) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=4.0->mantis-tsfm) (1.22.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23->mantis-tsfm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.23->mantis-tsfm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.23->mantis-tsfm) (0.1.2)
# Downloading mantis_tsfm-1.0.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.1 MB/s eta 0:00:00
# Downloading aeon-1.3.0-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 66.8 MB/s eta 0:00:00
# Downloading tirex_ts-1.4.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 4.4 MB/s eta 0:00:00
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading safetensors-0.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.8/434.8 kB 21.5 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 19.3 MB/s eta 0:00:00
# Installing collected packages: scipy, safetensors, deprecated, aeon, tirex-ts, mantis-tsfm
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
# Successfully installed aeon-1.3.0 deprecated-1.3.1 mantis-tsfm-1.0.0 safetensors-0.4.5 scipy-1.15.3 tirex-ts-1.4.0

# %% [markdown]
# ## Part 1: Time Series Classification
#
# In this part you will compare MANTIS and MultiROCKET on the UCI HAR dataset,
# then optionally combine their features.
#
# **Question 1.** Download the UCI HAR classification dataset (if needed) and
# prepare the train/test arrays. Use the code below so that `X_train`, `y_train`,
# `X_test`, `y_test` are available with shapes suitable for the classifiers
# (e.g. `X_*` of shape `(n_samples, n_channels, n_timesteps)` for aeon/MANTIS).

# %%
# !wget -O data/UCIHAR.npz https://github.com/rtavenar/ml-datasets/releases/download/UCIHAR/UCIHAR.npz
# Out:
# data/UCIHAR.npz: No such file or directory

# %%
import numpy as np

dataset = np.load("/content/UCIHAR.npz")

X_train, y_train = dataset["X_train"], dataset["y_train"]
X_test, y_test = dataset["X_test"], dataset["y_test"]

X_train.shape, X_test.shape
# Out:
# ((7352, 128, 9), (2947, 128, 9))

# %%
X_train = X_train.swapaxes(1, 2)
y_train = y_train.ravel()
X_test = X_test.swapaxes(1, 2)
y_test = y_test.ravel()

# %% [markdown]
# **Question 2.** Use **MANTIS** from the `mantis-tsfm` module: load the pre-trained
# Mantis8M model, extract embeddings on the training and test sets with `transform`,
# then train a linear classifier (e.g. logistic regression) on the extracted features
# and report test accuracy.

# %%
from mantis.architecture import Mantis8M
from mantis.trainer import MantisTrainer

network = Mantis8M(device='cpu')
network = network.from_pretrained('paris-noah/Mantis-8M')

model_mantis = MantisTrainer(network=network, device='cpu')

Z_train_mantis = model_mantis.transform(X_train)
Z_test_mantis = model_mantis.transform(X_test)

from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(l1_ratio=1., random_state=0).fit(Z_train_mantis, y_train)
clf.score(Z_test_mantis, y_test)

# %% [markdown]
# **Question 3.** Use **MultiROCKET** from the `aeon` library: fit the MultiRocket
# transformer on the training set, extract features on train and test, train a
# linear classifier on these features, and report test accuracy. Compare this
# accuracy with the one obtained with MANTIS in Question 2.

# %%
from aeon.transformations.collectio.convolution_based import MultiRocket

model_mr = MultiRocket(n_kernels=512)
Z_train_mr = model_mr.fit_transform(X_train)
clf = LogisticRegression(l1_ratio=1., random_state=0).fit(Z_train_mr, y_train)

Z_test_mr = model_mr.transform(X_test)
clf.score(Z_test_mr, y_test)

# %% [markdown]
# **Question 4.** Concatenate the MANTIS and MultiROCKET feature vectors and train a linear classifier on the
# combined features. Does combining both representations improve test accuracy
# compared to using either one alone?

# %%
Z_train_concat = np.concatenate((Z_train_mantis, Z_train_mr), axis=1)
Z_test_concat = np.concatenate((Z_test_mantis, Z_test_mr), axis=1)
clf = LogisticRegression(random_state=0).fit(Z_train_concat, y_train)
clf.score(Z_test_concat, y_test)

# %% [markdown]
# ## Part 2: Probabilistic Forecasting with TiReX
#
# In this part you will use the **TiReX** foundation model for time series
# forecasting on the univariate ETTh1 series and visualize probabilistic
# predictions.
#
# **Question 5.** Use the DataLoader below for ETTh1
# (e.g. context length 96, horizon 96). Load the pre-trained TiReX model from
# the `tirex-ts` module and produce probabilistic forecasts (e.g. mean and
# quantiles) on a batch of windows. Plot the past observations, ground-truth
# future, mean prediction, and 80%-level uncertainty interval for a few samples.

# %%
import torch
class ForecastingDataset(torch.utils.data.Dataset):
    """Windowed univariate forecasting dataset."""

    def __init__(self,
                 csv_path: str,
                 window: int,
                 horizon: int,
                 target_col: int = -1):
        super().__init__()
        raw = np.loadtxt(csv_path, delimiter=",", skiprows=1, usecols=target_col)
        series = raw.astype(np.float32)
        self.window = window
        self.horizon = horizon
        self.series = series
        self.max_start = len(series) - window - horizon + 1
        if self.max_start < 1:
            raise ValueError("Window + horizon larger than available series length")

    def __len__(self):
        return self.max_start

    def __getitem__(self, idx: int):
        start = idx
        past = self.series[start : start + self.window]
        future = self.series[start + self.window : start + self.window + self.horizon]
        past = torch.from_numpy(past)  # shape: (window,)
        future = torch.from_numpy(future)  # shape: (horizon,)
        return past, future


def build_dataloader(csv_path: str,
                     window: int,
                     horizon: int,
                     batch_size: int = 32,
                     shuffle: bool = True):
    """Create a DataLoader emitting `(past, horizon)` batches."""
    dataset = ForecastingDataset(csv_path=csv_path,
                                 window=window,
                                 horizon=horizon)
    return torch.utils.data.DataLoader(dataset,
                                       batch_size=batch_size,
                                       shuffle=shuffle,
                                       drop_last=False)

# %%
import matplotlib.pyplot as plt
def visualize_probabilistic_forecast(model, dataloader, n_samples=3):
    """Visualize probabilistic forecasts with uncertainty intervals."""
    model.eval()
    past, future = next(iter(dataloader))
    with torch.no_grad():
        # TODO here: generate a forecast from the model
        quantiles, mean = model.forecast(past, prediction_length=future.shape[1])

    for i in range(min(n_samples, past.shape[0])):
        # Plot past
        t_past = np.arange(past.shape[1])
        plt.plot(t_past, past[i].numpy(), 'b-', linewidth=2, label='Past observations')

        # Plot future
        t_future = np.arange(past.shape[1], past.shape[1] + future.shape[1])
        plt.plot(t_future, future[i].numpy(), 'g-', linewidth=2, label='Ground truth')

        # Plot mean prediction
        plt.plot(t_future, mean[i].numpy(), 'r--', linewidth=2, label='Mean prediction')

        # Plot uncertainty bands
        plt.fill_between(t_future, quantiles[i, :, 0].numpy(), quantiles[i, :, -1].numpy(), alpha=0.2, color='red', label='80% interval')

        plt.axvline(x=past.shape[1]-0.5, color='gray', linestyle=':', alpha=0.5)
        plt.legend()
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.title(f'Probabilistic Forecast (Sample {i+1})')
        plt.show()

# %%
from tirex import load_model, ForecastModel
import matplotlib.pyplot as plt

dataloader = build_dataloader("data/ETTh1.csv", window=96, horizon=96)
model: ForecastModel = load_model("NX-AI/TiRex")
visualize_probabilistic_forecast(model, dataloader, n_samples=3)
