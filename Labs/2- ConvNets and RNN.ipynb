# %% [markdown]
# # RNNs for Time Series Forecasting
#
# In this lab, you will explore recurrent models (RNN, GRU, LSTM, xLSTM) and
# temporal convolutions (CNN/TCN) for forecasting. You will work on two tasks:
# 1) a synthetic long-range-dependency dataset, and 2) the multivariate ETTh1 dataset.

# %%
import math
import numpy
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1 — Toy data for long-term memory experiments
#
# We build a synthetic sequence where a short spike far in the past determines a
# pattern in the future (e.g., a sine burst at a fixed lag). This stresses
# long-range credit assignment.

# %% [markdown]
# The dataset below is composed of sequences with:
# - a base noisy sine
# - a unique spike placed uniformly in the first half
# - a sine is located in the target at a fixed lag
#   after the spike occurred in the base

# %%
class SpikeLagDataset(torch.utils.data.Dataset):
    """Synthetic long-range-dependency dataset."""

    def __init__(self, length=200, lag=80, n_samples=5000, noise=0.05):
        self.length = length
        self.lag = lag
        self.n_samples = n_samples
        self.noise = noise

    def __len__(self):
        return self.n_samples

    def __getitem__(self, idx):
        t = torch.linspace(0, 4 * math.pi, self.length)
        base = torch.sin(t) + self.noise * torch.randn_like(t)
        spike_pos = torch.randint(10, self.length // 2, (1,)).item()
        spike = torch.zeros_like(base)
        spike[spike_pos] = 3.0
        series = base + spike
        target = torch.zeros(self.length)
        target[spike_pos + self.length // 4 :spike_pos + self.length // 2] = torch.sin(
            t[:self.length // 4]
        )
        return series.unsqueeze(-1), target.unsqueeze(-1)

def build_spike_dataloaders(length=200, lag=80, batch_size=64, n_train=4000, n_valid=500):
    train_ds = SpikeLagDataset(length=length, lag=lag, n_samples=n_train)
    valid_ds = SpikeLagDataset(length=length, lag=lag, n_samples=n_valid)
    train_dl = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    valid_dl = torch.utils.data.DataLoader(valid_ds, batch_size=batch_size, shuffle=False)
    return train_dl, valid_dl
train_dl, valid_dl = build_spike_dataloaders()

# %% [markdown]
# **Question.** Visualize a few series from this dataset.

# %%
def plot_spike_samples(dataset, n=3):
    fig, axs = plt.subplots(n, 1, figsize=(8, 6))
    for i in range(n):
        x, y = dataset[i]
        axs[i].plot(range(len(x)), x.numpy(), label="input")
        axs[i].plot(range(len(x), len(x) + len(y)), y.numpy(), label="target")
        axs[i].legend()
    plt.show()

length, lag, n_train = 200, 80, 10
dataset = SpikeLagDataset(length=length, lag=lag, n_samples=n_train)
plot_spike_samples(dataset, n_train)

# %% [markdown]
# **Question.** Implement a simple RNN forecaster:
# - Use `nn.RNN`, process the full sequence, and map the final hidden state to
#   the target segment with a linear head.
# - Report train/valid loss (MSE).

# %%
def train_epoch(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0.0
    for x, y in dataloader:
        optimizer.zero_grad()
        pred = model(x)  # pred: (batch, horizon, 1)
        loss = criterion(pred, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * x.size(0)
    return total_loss / len(dataloader.dataset)


@torch.no_grad()
def eval_epoch(model, dataloader, criterion):
    model.eval()
    total_loss = 0.0
    for x, y in dataloader:
        pred = model(x)
        loss = criterion(pred, y)
        total_loss += loss.item() * x.size(0)
    return total_loss / len(dataloader.dataset)

def train_and_valid_loop(model, train_dl, valid_dl, optimizer, criterion, n_epochs):
    logs = {"train_loss": [], "valid_loss": []}
    print(model.__class__.__name__)
    for epoch in range(n_epochs):
        train_loss = train_epoch(model, train_dl, optimizer, criterion)
        logs["train_loss"].append(train_loss)
        valid_loss = eval_epoch(model, valid_dl, criterion)
        logs["valid_loss"].append(valid_loss)
        print(f"Epoch {epoch:02d} | train={train_loss:.4f} | valid={valid_loss:.4f}")
    return logs

# %%
class RNNForecaster(torch.nn.Module):
    def __init__(self, input_dim, hidden, horizon):
        super().__init__()
        self.rnn = torch.nn.RNN(input_dim, hidden, batch_first=True)
        self.horizon = horizon
        self.head = torch.nn.Linear(hidden, horizon)

    def forward(self, x):
        out, h = self.rnn(x)
        h_last = h[0]
        pred= self.head(h_last)
        return pred.unsqueeze(-1)

hidden_dim = 64
rnn = RNNForecaster(1, hidden_dim, length)
optimizer = torch.optim.Adam(rnn.parameters(), lr=1e-3)
criterion = torch.nn.MSELoss()
logs = train_and_valid_loop(rnn, train_dl, valid_dl, optimizer, criterion, n_epochs=20)
# Out:
# RNNForecaster
# Epoch 00 | train=0.0859 | valid=0.0775
# Epoch 01 | train=0.0767 | valid=0.0775
# Epoch 02 | train=0.0766 | valid=0.0754
# Epoch 03 | train=0.0762 | valid=0.0759
# Epoch 04 | train=0.0765 | valid=0.0756
# Epoch 05 | train=0.0764 | valid=0.0772
# Epoch 06 | train=0.0770 | valid=0.0763
# Epoch 07 | train=0.0762 | valid=0.0766
# Epoch 08 | train=0.0769 | valid=0.0769
# Epoch 09 | train=0.0764 | valid=0.0759
# Epoch 10 | train=0.0770 | valid=0.0764
# Epoch 11 | train=0.0766 | valid=0.0766
# Epoch 12 | train=0.0765 | valid=0.0767
# Epoch 13 | train=0.0765 | valid=0.0771
# Epoch 14 | train=0.0763 | valid=0.0759
# Epoch 15 | train=0.0762 | valid=0.0756
# Epoch 16 | train=0.0764 | valid=0.0773
# Epoch 17 | train=0.0767 | valid=0.0770
# Epoch 18 | train=0.0762 | valid=0.0776
# Epoch 19 | train=0.0765 | valid=0.0752

# %% [markdown]
# **Question.** Replace the RNN with GRU and LSTM. Compare:
# - convergence speed and final validation loss
# - qualitative forecasts

# %%
class GRUForecaster(RNNForecaster):
    def __init__(self, input_dim=1, hidden=64, horizon=200):
        super().__init__(input_dim, hidden, horizon)
        self.rnn = torch.nn.GRU(input_dim, hidden, batch_first=True)


class LSTMForecaster(RNNForecaster):
    def __init__(self, input_dim=1, hidden=64, horizon=200):
        super().__init__(input_dim, hidden, horizon)
        self.rnn = torch.nn.LSTM(input_dim, hidden, batch_first=True)

    def forward(self, x):
        out, (h, c) = self.rnn(x)  # h: (1, batch, hidden)
        h_last = h[0]
        pred = self.head(h_last)
        return pred.unsqueeze(-1)  # (batch, horizon, 1)

hidden_dim = 64
gru = GRUForecaster(hidden=hidden_dim, horizon=length)
opt = torch.optim.Adam(gru.parameters(), lr=1e-3)
criterion = torch.nn.MSELoss()
logs_gru = train_and_valid_loop(gru, train_dl, valid_dl, opt, criterion, n_epochs=20)

hidden_dim = 64
lstm = LSTMForecaster(hidden=hidden_dim, horizon=length)
opt = torch.optim.Adam(lstm.parameters(), lr=1e-3)
criterion = torch.nn.MSELoss()
logs_lstm = train_and_valid_loop(lstm, train_dl, valid_dl, opt, criterion, n_epochs=20)
# Out:
# GRUForecaster
# Epoch 00 | train=0.0894 | valid=0.0767
# Epoch 01 | train=0.0761 | valid=0.0757
# Epoch 02 | train=0.0760 | valid=0.0741
# Epoch 03 | train=0.0764 | valid=0.0771
# Epoch 04 | train=0.0764 | valid=0.0771
# Epoch 05 | train=0.0764 | valid=0.0765
# Epoch 06 | train=0.0764 | valid=0.0774
# Epoch 07 | train=0.0764 | valid=0.0762
# Epoch 08 | train=0.0762 | valid=0.0771
# Epoch 09 | train=0.0763 | valid=0.0764
# Epoch 10 | train=0.0765 | valid=0.0748
# Epoch 11 | train=0.0765 | valid=0.0774
# Epoch 12 | train=0.0770 | valid=0.0765
# Epoch 13 | train=0.0762 | valid=0.0778
# Epoch 14 | train=0.0762 | valid=0.0754
# Epoch 15 | train=0.0765 | valid=0.0777
# Epoch 16 | train=0.0763 | valid=0.0756
# Epoch 17 | train=0.0771 | valid=0.0767
# Epoch 18 | train=0.0767 | valid=0.0761
# Epoch 19 | train=0.0765 | valid=0.0761
# LSTMForecaster
# Epoch 00 | train=0.0918 | valid=0.0767
# Epoch 01 | train=0.0764 | valid=0.0759
# Epoch 02 | train=0.0765 | valid=0.0761
# Epoch 03 | train=0.0764 | valid=0.0778
# Epoch 04 | train=0.0765 | valid=0.0762
# Epoch 05 | train=0.0759 | valid=0.0760
# Epoch 06 | train=0.0770 | valid=0.0767
# Epoch 07 | train=0.0764 | valid=0.0770
# Epoch 08 | train=0.0768 | valid=0.0756
# Epoch 09 | train=0.0767 | valid=0.0771
# Epoch 10 | train=0.0766 | valid=0.0777
# Epoch 11 | train=0.0770 | valid=0.0763
# Epoch 12 | train=0.0767 | valid=0.0765
# Epoch 13 | train=0.0766 | valid=0.0769
# Epoch 14 | train=0.0761 | valid=0.0770
# Epoch 15 | train=0.0764 | valid=0.0759
# Epoch 16 | train=0.0766 | valid=0.0778
# Epoch 17 | train=0.0761 | valid=0.0759
# Epoch 18 | train=0.0765 | valid=0.0758
# Epoch 19 | train=0.0763 | valid=0.0766

# %% [markdown]
# The code below provides implementation for a TCN block.

# %%
from torch.nn.utils.parametrizations import weight_norm

class CausalConv(torch.nn.Module):
    """Minimal 1D causal convolution block without activation."""

    def __init__(self, in_ch, out_ch, k=3, d=1):
        super().__init__()
        self.pad = (k - 1) * d
        self.conv = weight_norm(torch.nn.Conv1d(in_ch, out_ch, k, dilation=d))

    def forward(self, x):
        x = torch.nn.functional.pad(x, (self.pad, 0))
        return self.conv(x)

class TCNBlock(torch.nn.Module):
    """A TCN block involving 2 dilated convolutions."""

    def __init__(self, in_ch, out_ch, k=3, d1=1, d2=2, dropout_rate=.1):
        super().__init__()
        self.conv1 = CausalConv(in_ch, out_ch, k, d1)
        self.conv2 = CausalConv(out_ch, out_ch, k, d2)
        # 1x1 conv to project residual to the correct number of channels
        self.conv_1x1 = torch.nn.Conv1d(in_ch, out_ch, kernel_size=1)
        self.do1 = torch.nn.Dropout1d(p=dropout_rate)
        self.do2 = torch.nn.Dropout1d(p=dropout_rate)
        self.act = torch.nn.ReLU()

    def forward(self, x):
        residual = self.conv_1x1(x)
        out = self.conv1(x)
        out = self.act(out)
        out = self.do1(out)
        out = self.conv2(out)
        out = self.act(out)
        out = self.do2(out)
        return self.act(out + residual)  # (batch, channels, time)

# %% [markdown]
# **Question.** Based on the above implementation, try the following TCN baselines
# for your forecasting problem:
# - 1D causal CNN with dilations (a 1-block TCN).
# - Stack several TCN blocks such that the receptive field is sufficient for the task at stake.
# Compare against RNN/GRU/LSTM on the spike-lag task.

# %%
class TCNForecaster(torch.nn.Module):
    def __init__(self, input_dim=1, hidden=64, n_blocks=3, k=3, horizon=200):
        super().__init__()
        blocks = []
        ch_in = input_dim
        for i in range(n_blocks):
            blocks.append(TCNBlock(ch_in, hidden, k, d1=2 ** (2*i), d2=2 ** (2*i+1)))
            ch_in = hidden
        self.net = torch.nn.Sequential(*blocks)
        self.head = torch.nn.Linear(hidden, horizon)

    def forward(self, x):
        x = x.transpose(1, 2)  # (batch, channels, time)
        feats = self.net(x)
        last_feat = feats[:, :, -1]
        pred = self.head(last_feat)
        return pred.unsqueeze(-1)

hidden_dim = 64
tcn = TCNForecaster(hidden=hidden_dim, horizon=length)
opt = torch.optim.Adam(tcn.parameters(), lr=1e-3)
criterion = torch.nn.MSELoss()
logs_tcn = train_and_valid_loop(tcn, train_dl, valid_dl, opt, criterion, n_epochs=10)

dict_logs = {
    "TCN": logs_tcn,
    "RNN": logs,
    "LSTM": logs_lstm,
    "GRU": logs_gru
}
for label, logs in dict_logs.items():
    plt.plot(logs["valid_loss"], label=label)
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()


dict_models = {
    "TCN": tcn,
    "RNN": rnn,
    "LSTM": lstm,
    "GRU": gru
}
for i in range(3):
    past, future = dataset[i]
    plt.figure()
    plt.plot(range(length), past.numpy())
    plt.plot(range(length, 2*length), future.numpy(), label="Ground truth")
    for label, model in dict_models.items():
        pred = model(past.unsqueeze(0))[0]
        plt.plot(range(length, 2*length), pred.flatten().detach().numpy(), label=label)
    plt.legend()
    plt.show()
# Out:
# TCNForecaster
# Epoch 00 | train=0.0863 | valid=0.0760
# Epoch 01 | train=0.0763 | valid=0.0766
# Epoch 02 | train=0.0677 | valid=0.0516
# Epoch 03 | train=0.0494 | valid=0.0444
# Epoch 04 | train=0.0458 | valid=0.0421
# Epoch 05 | train=0.0447 | valid=0.0465
# Epoch 06 | train=0.0450 | valid=0.0402
# Epoch 07 | train=0.0447 | valid=0.0430
# Epoch 08 | train=0.0437 | valid=0.0425
# Epoch 09 | train=0.0450 | valid=0.0420
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-246/3728624755.py in <cell line: 0>()
#      49     plt.plot(range(length, 2*length), future.numpy(), label="Ground truth")
#      50     for label, model in dict_models.items():
# ---> 51         pred = model(past.unsqueeze(0))[0]
#      52         plt.plot(range(length, 2*length), pred.flatten().detach().numpy(), label=label)
#      53     plt.legend()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /tmp/ipython-input-246/288728511.py in forward(self, x)
#       7
#       8     def forward(self, x):
# ----> 9         out, h = self.rnn(x)
#      10         h_last = h[0]
#      11         pred= self.head(h_last)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#    1411                 hx = self.permute_hidden(hx, sorted_indices)
#    1412
# -> 1413         self.check_forward_args(input, hx, batch_sizes)
#    1414         if batch_sizes is None:
#    1415             result = _VF.gru(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     365         self, input: Tensor, hidden: Tensor, batch_sizes: Tensor | None
#     366     ) -> None:
# --> 367         self.check_input(input, batch_sizes)
#     368         expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     369
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py in check_input(self, input, batch_sizes)
#     314             )
#     315         if self.input_size != input.size(-1):
# --> 316             raise RuntimeError(
#     317                 f"input.size(-1) must be equal to input_size. Expected {self.input_size}, got {input.size(-1)}"
#     318             )
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 8, got 1

# %% [markdown]
# ## Part 2 — Multivariate ETTh1 forecasting
#
# We now revisit ETTh1 used in the previous lab session but now
# treat it as a multivariate-to-univariate
# forecasting problem.

# %% [markdown]
# Below is an adaptation from last session's `ETTh1Dataset` class in which we:
# - Allow specifying `window`, `horizon`, and optional time-of-day encoding
#   (scaled to [0, 1]).
# - Return tensors shaped `(batch, time, features)` where features>1 for input
#   tensors and features=1 for output tensor (target).

# %%
def load_etth1(csv_path, use_time_feat=True):
    def to_str(str_or_bytes):
        if isinstance(str, str_or_bytes):
            return str_or_bytes
        else:
            return str_or_bytes.decode()

    d_conv = {
        0: (lambda x: float(to_str(x).split(" ")[1].split(":")[0]))
    }
    raw = numpy.loadtxt(csv_path, delimiter=",", skiprows=1, converters=d_conv)
    features = raw.astype(numpy.float32)
    if use_time_feat:
        features[:, 0] /= 23.
    else:
        features = features[:, 1:]
    return features


class ETTh1Dataset(torch.utils.data.Dataset):
    def __init__(self, csv_path, window, horizon, use_time_feat=True, start=0, end=None, mean=None, std=None):
        feats = load_etth1(csv_path, use_time_feat=use_time_feat)
        feats = feats[start:]
        if end is not None:
            feats = feats[:end]
        self.feats = feats
        self.window = window
        self.horizon = horizon
        self.max_start = len(feats) - window - horizon + 1
        if self.max_start < 1:
            raise ValueError("Window + horizon exceeds series length")
        self.mean = mean
        self.std = std

    def __len__(self):
        return self.max_start

    def __getitem__(self, idx):
        past = self.feats[idx : idx + self.window]
        future = self.feats[idx + self.window : idx + self.window + self.horizon, -1:]
        # Apply scaling if mean and std are provided
        if self.mean is not None and self.std is not None:
            past = (past - self.mean) / self.std
            future = (future - self.mean[-1:]) / self.std[-1:]
        return torch.from_numpy(past), torch.from_numpy(future)

# %% [markdown]
# **Question.** Based on the `ETTh1Dataset` class provided above, implement
# a `build_etth1_dataloaders` function that generates training and validation
# data loaders, with scaling. Load the data relying on a past window of size 96
# and a horizon of 24 time steps.

# %%
def build_etth1_dataloaders(csv_path, window=96, horizon=24, batch_size=64, split=0.8):
    dataset = ETTh1Dataset(csv_path, window, horizon)
    n = len(dataset)
    n_train = int(split * n)
    train_ds = ETTh1Dataset(csv_path, window, horizon, end=n_train)
    mean = numpy.mean(train_ds.feats, axis=0)  # (n_features,)
    std = numpy.std(train_ds.feats, axis=0)  # (n_features,)
    std = numpy.where(std < 1e-8, 1.0, std)

    # Create datasets with scaling
    train_ds = ETTh1Dataset(csv_path, window, horizon, end=n_train, mean=mean, std=std)
    valid_ds = ETTh1Dataset(csv_path, window, horizon, start=n_train, mean=mean, std=std)
    train_dl = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    valid_dl = torch.utils.data.DataLoader(valid_ds, batch_size=batch_size, shuffle=False)
    return train_dl, valid_dl

window = 96
horizon = 24
dataset = ETTh1Dataset("/content/ETTh1.csv", window=window, horizon=horizon)
train_dl, valid_dl = build_etth1_dataloaders("data/ETTh1.csv", window=window, horizon=horizon)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-246/3586308305.py in <lambda>(x)
#       8     d_conv = {
# ----> 9         0: (lambda x: float(to_str(x).split(" ")[1].split(":")[0]))
#      10     }
#
# /tmp/ipython-input-246/3586308305.py in to_str(str_or_bytes)
#       2     def to_str(str_or_bytes):
# ----> 3         if isinstance(str, str_or_bytes):
#       4             return str_or_bytes
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-246/2968095729.py in <cell line: 0>()
#      17 window = 96
#      18 horizon = 24
# ---> 19 dataset = ETTh1Dataset("/content/ETTh1.csv", window=window, horizon=horizon)
#      20 train_dl, valid_dl = build_etth1_dataloaders("data/ETTh1.csv", window=window, horizon=horizon)
#
# /tmp/ipython-input-246/3586308305.py in __init__(self, csv_path, window, horizon, use_time_feat, start, end, mean, std)
#      20 class ETTh1Dataset(torch.utils.data.Dataset):
#      21     def __init__(self, csv_path, window, horizon, use_time_feat=True, start=0, end=None, mean=None, std=None):
# ---> 22         feats = load_etth1(csv_path, use_time_feat=use_time_feat)
#      23         feats = feats[start:]
#      24         if end is not None:
#
# /tmp/ipython-input-246/3586308305.py in load_etth1(csv_path, use_time_feat)
#       9         0: (lambda x: float(to_str(x).split(" ")[1].split(":")[0]))
#      10     }
# ---> 11     raw = numpy.loadtxt(csv_path, delimiter=",", skiprows=1, converters=d_conv)
#      12     features = raw.astype(numpy.float32)
#      13     if use_time_feat:
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1379         delimiter = delimiter.decode('latin1')
#    1380
# -> 1381     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1383                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1019
#    1020         if read_dtype_via_object_chunks is None:
# -> 1021             arr = _load_from_filelike(
#    1022                 data, delimiter=delimiter, comment=comment, quote=quote,
#    1023                 imaginary_unit=imaginary_unit,
#
# ValueError: could not convert string '2016-07-01 00:00:00' to float64 at row 0, column 1.

# %% [markdown]
# **Question.** Re-use TCN and GRU forecasting models from part 1 and
# evaluate their performance on this dataset.
# Does the TCN's receptive field cover the whole input window in this case?

# %%
hidden_dim = 64
channels = 8
horizon = 24
gru = GRUForecaster(input_dim=channels, hidden=hidden_dim, horizon=horizon)
opt = torch.optim.Adam(gru.parameters(), lr=1e-3)
criterion = torch.nn.MSELoss()
logs_gru = train_and_valid_loop(gru, train_dl, valid_dl, opt, criterion, n_epochs=20)

tcn = TCNForecaster(input_dim=channels, hidden_dim=hidden_dim, horizon=horizon)
opt = torch.optim.Adam(tcn.parameters(), lr=1e-3)
criterion = torch.nn.MSELoss()
logs_tcn = train_and_valid_loop(tcn, train_dl, valid_dl, opt, criterion, n_epochs=20)

dict_models = {
    "TCN": tcn,
    "GRU": gru
}
it = iter(valid_dl)
for i in range(3):
    past, future = next(it)
    plt.figure()
    plt.plot(range(window), past[0, :, -1].numpy())
    plt.plot(range(window, window + horizon), future[0].numpy(), label="Ground truth")
    for label, model in dict_models.items():
        pred = model(past)[0]
        plt.plot(range(window, window + horizon), pred.flatten().detach().numpy(), label=label)
    plt.legend()
    plt.show()
# Out:
# GRUForecaster
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-246/1818721585.py in <cell line: 0>()
#       5 opt = torch.optim.Adam(gru.parameters(), lr=1e-3)
#       6 criterion = torch.nn.MSELoss()
# ----> 7 logs_gru = train_and_valid_loop(gru, train_dl, valid_dl, opt, criterion, n_epochs=20)
#       8
#       9 tcn = TCNForecaster(input_dim=channels, hidden_dim=hidden_dim, horizon=horizon)
#
# /tmp/ipython-input-246/2307579664.py in train_and_valid_loop(model, train_dl, valid_dl, optimizer, criterion, n_epochs)
#      26     print(model.__class__.__name__)
#      27     for epoch in range(n_epochs):
# ---> 28         train_loss = train_epoch(model, train_dl, optimizer, criterion)
#      29         logs["train_loss"].append(train_loss)
#      30         valid_loss = eval_epoch(model, valid_dl, criterion)
#
# /tmp/ipython-input-246/2307579664.py in train_epoch(model, dataloader, optimizer, criterion)
#       4     for x, y in dataloader:
#       5         optimizer.zero_grad()
# ----> 6         pred = model(x)  # pred: (batch, horizon, 1)
#       7         loss = criterion(pred, y)
#       8         loss.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /tmp/ipython-input-246/288728511.py in forward(self, x)
#       7
#       8     def forward(self, x):
# ----> 9         out, h = self.rnn(x)
#      10         h_last = h[0]
#      11         pred= self.head(h_last)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#    1411                 hx = self.permute_hidden(hx, sorted_indices)
#    1412
# -> 1413         self.check_forward_args(input, hx, batch_sizes)
#    1414         if batch_sizes is None:
#    1415             result = _VF.gru(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     365         self, input: Tensor, hidden: Tensor, batch_sizes: Tensor | None
#     366     ) -> None:
# --> 367         self.check_input(input, batch_sizes)
#     368         expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     369
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py in check_input(self, input, batch_sizes)
#     314             )
#     315         if self.input_size != input.size(-1):
# --> 316             raise RuntimeError(
#     317                 f"input.size(-1) must be equal to input_size. Expected {self.input_size}, got {input.size(-1)}"
#     318             )
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 8, got 1

# %% [markdown]
# **Question.** Now you will use the code from the `xlstm` package to build an xLSTM
# model for this forecasting task.
# - What stack of sLSTM/mLSTM blocks is used here?

# %%
# %pip install xlstm
# Out:
# Collecting xlstm
#   Downloading xlstm-2.0.5-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from xlstm) (2.10.0+cpu)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from xlstm) (0.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xlstm) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from xlstm) (3.4.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from xlstm) (2.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from xlstm) (5.0.0)
# Collecting reportlab (from xlstm)
#   Downloading reportlab-4.4.10-py3-none-any.whl.metadata (1.7 kB)
# Collecting joypy (from xlstm)
#   Downloading joypy-0.2.6-py2.py3-none-any.whl.metadata (812 bytes)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from xlstm) (6.17.1)
# Collecting dacite (from xlstm)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting ftfy (from xlstm)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting ninja (from xlstm)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from xlstm) (1.4.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from xlstm) (13.9.4)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from xlstm) (0.22.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from xlstm) (4.67.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from xlstm) (0.13.2)
# Collecting mlstm_kernels (from xlstm)
#   Downloading mlstm_kernels-2.0.2-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->xlstm) (0.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (6.0.3)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->xlstm) (4.15.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->xlstm) (5.7.1)
# Requirement already satisfied: scipy>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from joypy->xlstm) (1.16.3)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from joypy->xlstm) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from joypy->xlstm) (3.10.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->xlstm) (4.9.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from reportlab->xlstm) (11.3.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from reportlab->xlstm) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->xlstm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->xlstm) (2.19.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->xlstm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->xlstm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->xlstm) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->xlstm) (3.1.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->xlstm) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->xlstm) (0.7.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->xlstm) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->xlstm) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->xlstm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->xlstm) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->xlstm) (0.16.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->xlstm)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->xlstm) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->xlstm) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->xlstm) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->xlstm) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->xlstm) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->xlstm) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->xlstm) (5.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->xlstm) (2.9.0.post0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->xlstm) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy->xlstm) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy->xlstm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy->xlstm) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy->xlstm) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy->xlstm) (3.3.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.0->joypy->xlstm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.0->joypy->xlstm) (2025.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->xlstm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->xlstm) (3.0.3)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub->xlstm) (0.24.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->xlstm) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->xlstm) (4.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->xlstm) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->xlstm) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub->xlstm) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub->xlstm) (0.0.4)
# Downloading xlstm-2.0.5-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 8.9 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.1 MB/s eta 0:00:00
# Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Downloading mlstm_kernels-2.0.2-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 30.2 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.0 MB/s eta 0:00:00
# Downloading reportlab-4.4.10-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.7 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.8 MB/s eta 0:00:00
# Installing collected packages: reportlab, ninja, jedi, ftfy, dacite, joypy, mlstm_kernels, xlstm
# Successfully installed dacite-1.9.2 ftfy-6.3.1 jedi-0.19.2 joypy-0.2.6 mlstm_kernels-2.0.2 ninja-1.13.0 reportlab-4.4.10 xlstm-2.0.5

# %%
from xlstm.xlstm_block_stack import (
    xLSTMBlockStack,
    xLSTMBlockStackConfig,
)
from xlstm.blocks.mlstm.block import mLSTMBlockConfig
from xlstm.blocks.mlstm.layer import mLSTMLayerConfig

class xLSTMForecaster(torch.nn.Module):
    def __init__(
        self,
        input_dim: int,
        hidden_dim: int,
        num_blocks: int,
        window: int,
        horizon: int,
    ):
        super().__init__()

        # Project input channels → model dimension
        self.input_proj = torch.nn.Linear(input_dim, hidden_dim)

        # Build block configs (repeat to get depth)
        layer_config = mLSTMLayerConfig(
            embedding_dim=hidden_dim,
            num_heads=2,
        )
        block_cfg = mLSTMBlockConfig(
            mlstm=layer_config,
        )

        xlstm_cfg = xLSTMBlockStackConfig(
            mlstm_block=block_cfg,
            slstm_at=[],
            num_blocks=num_blocks,
            context_length=window,
            embedding_dim=hidden_dim
        )

        self.xlstm = xLSTMBlockStack(xlstm_cfg)

        # Forecast head
        self.head = torch.nn.Linear(hidden_dim, horizon)

    def forward(self, x):
        x = self.input_proj(x)        # (B, T, c)
        y = self.xlstm(x)             # (B, T, c)

        last_state = y[:, -1]         # (B, c)
        out = self.head(last_state)   # (B, H)

        return out.unsqueeze(-1)      # (B, H, 1)

# %% [markdown]
# **Question.** Train your own xLSTM forecaster and check its performance.

# %%
xlstm_model = xLSTMForecaster(
    input_dim=channels,
    hidden_dim=hidden_dim,
    num_blocks=1,
    horizon=horizon,
    window=window
)

opt = torch.optim.Adam(xlstm_model.parameters(), lr=1e-3)
criterion = torch.nn.MSELoss()
logs_xlstm = train_and_valid_loop(xlstm_model, train_dl, valid_dl, opt, criterion, n_epochs=10)
# Out:
# xLSTMForecaster
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-246/76250909.py in <cell line: 0>()
#       9 opt = torch.optim.Adam(xlstm_model.parameters(), lr=1e-3)
#      10 criterion = torch.nn.MSELoss()
# ---> 11 logs_xlstm = train_and_valid_loop(xlstm_model, train_dl, valid_dl, opt, criterion, n_epochs=10)
#
# /tmp/ipython-input-246/2307579664.py in train_and_valid_loop(model, train_dl, valid_dl, optimizer, criterion, n_epochs)
#      26     print(model.__class__.__name__)
#      27     for epoch in range(n_epochs):
# ---> 28         train_loss = train_epoch(model, train_dl, optimizer, criterion)
#      29         logs["train_loss"].append(train_loss)
#      30         valid_loss = eval_epoch(model, valid_dl, criterion)
#
# /tmp/ipython-input-246/2307579664.py in train_epoch(model, dataloader, optimizer, criterion)
#       4     for x, y in dataloader:
#       5         optimizer.zero_grad()
# ----> 6         pred = model(x)  # pred: (batch, horizon, 1)
#       7         loss = criterion(pred, y)
#       8         loss.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /tmp/ipython-input-246/2966328107.py in forward(self, x)
#      43
#      44     def forward(self, x):
# ---> 45         x = self.input_proj(x)        # (B, T, c)
#      46         y = self.xlstm(x)             # (B, T, c)
#      47
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     132         Runs the forward pass.
#     133         """
# --> 134         return F.linear(input, self.weight, self.bias)
#     135
#     136     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (12800x1 and 8x64)
